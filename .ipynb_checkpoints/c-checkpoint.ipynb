# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
sns.set()

# %%
df = pd.read_csv('Customers.csv')
df
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# 0        Healthcare                1            4
# 1          Engineer                3            3
# 2          Engineer                1            1
# 3            Lawyer                0            2
# 4     Entertainment                2            6
# ...             ...              ...          ...
# 1995         Artist                8            7
# 1996         Doctor                7            7
# 1997     Healthcare                9            2
# 1998      Executive                7            2
# 1999  Entertainment                5            2
#
# [2000 rows x 8 columns]

# %%
df.shape
# Out:
# (2000, 8)

# %%
df.describe(include = 'all')
# Out:
#          CustomerID  Gender          Age  Annual Income ($)  \
# count   2000.000000    2000  2000.000000        2000.000000
# unique          NaN       2          NaN                NaN
# top             NaN  Female          NaN                NaN
# freq            NaN    1186          NaN                NaN
# mean    1000.500000     NaN    48.960000      110731.821500
# std      577.494589     NaN    28.429747       45739.536688
# min        1.000000     NaN     0.000000           0.000000
# 25%      500.750000     NaN    25.000000       74572.000000
# 50%     1000.500000     NaN    48.000000      110045.000000
# 75%     1500.250000     NaN    73.000000      149092.750000
# max     2000.000000     NaN    99.000000      189974.000000
#
#         Spending Score (1-100) Profession  Work Experience  Family Size
# count              2000.000000       1965      2000.000000  2000.000000
# unique                     NaN          9              NaN          NaN
# top                        NaN     Artist              NaN          NaN
# freq                       NaN        612              NaN          NaN
# mean                 50.962500        NaN         4.102500     3.768500
# std                  27.934661        NaN         3.922204     1.970749
# min                   0.000000        NaN         0.000000     1.000000
# 25%                  28.000000        NaN         1.000000     2.000000
# 50%                  50.000000        NaN         3.000000     4.000000
# 75%                  75.000000        NaN         7.000000     5.000000
# max                 100.000000        NaN        17.000000     9.000000

# %%
df.dtypes
# Out:
# CustomerID                 int64
# Gender                    object
# Age                        int64
# Annual Income ($)          int64
# Spending Score (1-100)     int64
# Profession                object
# Work Experience            int64
# Family Size                int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# CustomerID                 0
# Gender                     0
# Age                        0
# Annual Income ($)          0
# Spending Score (1-100)     0
# Profession                35
# Work Experience            0
# Family Size                0
# dtype: int64

# %%
df.drop(['CustomerID'], axis = 1, inplace=True)

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#       Gender  Age  Annual Income ($)  Spending Score (1-100)     Profession  \
# 0       Male   19              15000                      39     Healthcare
# 1       Male   21              35000                      81       Engineer
# 2     Female   20              86000                       6       Engineer
# 3     Female   23              59000                      77         Lawyer
# 4     Female   31              38000                      40  Entertainment
# ...      ...  ...                ...                     ...            ...
# 1995  Female   71             184387                      40         Artist
# 1996  Female   91              73158                      32         Doctor
# 1997    Male   87              90961                      14     Healthcare
# 1998    Male   77             182109                       4      Executive
# 1999    Male   90             110610                      52  Entertainment
#
#       Work Experience  Family Size
# 0                   1            4
# 1                   3            3
# 2                   1            1
# 3                   0            2
# 4                   2            6
# ...               ...          ...
# 1995                8            7
# 1996                7            7
# 1997                9            2
# 1998                7            2
# 1999                5            2
#
# [1965 rows x 7 columns]

# %%
df.drop(df[df.Age <= 17].index, axis= 0, inplace=True)
df.drop(df[df.Age >= 91].index, axis= 0, inplace=True)

# %%
df.describe(include = 'all')
# Out:
#         Gender          Age  Annual Income ($)  Spending Score (1-100)  \
# count     1467  1467.000000        1467.000000             1467.000000
# unique       2          NaN                NaN                     NaN
# top     Female          NaN                NaN                     NaN
# freq       869          NaN                NaN                     NaN
# mean       NaN    52.584867      108207.462849               50.478528
# std        NaN    21.253909       46638.346529               27.833922
# min        NaN    18.000000           0.000000                0.000000
# 25%        NaN    34.000000       71846.000000               27.000000
# 50%        NaN    52.000000      106314.000000               49.000000
# 75%        NaN    70.000000      147376.500000               74.500000
# max        NaN    90.000000      189945.000000              100.000000
#
#        Profession  Work Experience  Family Size
# count        1467      1467.000000  1467.000000
# unique          9              NaN          NaN
# top        Artist              NaN          NaN
# freq          458              NaN          NaN
# mean          NaN         3.995228     3.721200
# std           NaN         3.881865     1.951837
# min           NaN         0.000000     1.000000
# 25%           NaN         1.000000     2.000000
# 50%           NaN         3.000000     4.000000
# 75%           NaN         7.000000     5.000000
# max           NaN        17.000000     9.000000

# %%
plt.figure(1, figsize = (15, 6))
n = 0
for x in ['Age', 'Annual Income ($)', 'Spending Score (1-100)', 'Work Experience', 'Family Size']:
    n += 1
    plt.subplot(1, 5, n)
    plt.subplots_adjust(hspace=0.5, wspace=0.5)
    sns.distplot(df[x])
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_36000\1228374403.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[x])
# C:\Users\user\AppData\Local\Temp\ipykernel_36000\1228374403.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[x])
# C:\Users\user\AppData\Local\Temp\ipykernel_36000\1228374403.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[x])
# C:\Users\user\AppData\Local\Temp\ipykernel_36000\1228374403.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[x])
# C:\Users\user\AppData\Local\Temp\ipykernel_36000\1228374403.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[x])

# %%
plt.figure(figsize = (15, 6))

plt.subplot(2, 1, 1)
sns.countplot(y = 'Gender', data = df)
plt.subplots_adjust(hspace=0.5, wspace=0.5)

plt.subplot(2, 1, 2)
sns.countplot(y = 'Profession', data = df)
plt.subplots_adjust(hspace=0.5, wspace=0.5)

plt.show()

# %%
df.Age[df.Age == 0].count()
# Out:
# 0

# %%
df['Spending Score (1-100)'].count()
# Out:
# 1467

# %%
sns.scatterplot(x = 'Annual Income ($)', y = 'Spending Score (1-100)', data=df)
# Out:
# <Axes: xlabel='Annual Income ($)', ylabel='Spending Score (1-100)'>

# %%
df1 = pd.get_dummies(df[["Profession","Gender"]])
df1
# Out:
#       Profession_Artist  Profession_Doctor  Profession_Engineer  \
# 0                     0                  0                    0
# 1                     0                  0                    1
# 2                     0                  0                    1
# 3                     0                  0                    0
# 4                     0                  0                    0
# ...                 ...                ...                  ...
# 1994                  0                  0                    1
# 1995                  1                  0                    0
# 1997                  0                  0                    0
# 1998                  0                  0                    0
# 1999                  0                  0                    0
#
#       Profession_Entertainment  Profession_Executive  Profession_Healthcare  \
# 0                            0                     0                      1
# 1                            0                     0                      0
# 2                            0                     0                      0
# 3                            0                     0                      0
# 4                            1                     0                      0
# ...                        ...                   ...                    ...
# 1994                         0                     0                      0
# 1995                         0                     0                      0
# 1997                         0                     0                      1
# 1998                         0                     1                      0
# 1999                         1                     0                      0
#
#       Profession_Homemaker  Profession_Lawyer  Profession_Marketing  \
# 0                        0                  0                     0
# 1                        0                  0                     0
# 2                        0                  0                     0
# 3                        0                  1                     0
# 4                        0                  0                     0
# ...                    ...                ...                   ...
# 1994                     0                  0                     0
# 1995                     0                  0                     0
# 1997                     0                  0                     0
# 1998                     0                  0                     0
# 1999                     0                  0                     0
#
#       Gender_Female  Gender_Male
# 0                 0            1
# 1                 0            1
# 2                 1            0
# 3                 1            0
# 4                 1            0
# ...             ...          ...
# 1994              1            0
# 1995              1            0
# 1997              0            1
# 1998              0            1
# 1999              0            1
#
# [1467 rows x 11 columns]

# %%
df.drop(["Profession","Gender"], inplace = True, axis=1)

# %%
df = pd.concat([df1], axis = 1)
df
# Out:
#       Profession_Artist  Profession_Doctor  Profession_Engineer  \
# 0                     0                  0                    0
# 1                     0                  0                    1
# 2                     0                  0                    1
# 3                     0                  0                    0
# 4                     0                  0                    0
# ...                 ...                ...                  ...
# 1994                  0                  0                    1
# 1995                  1                  0                    0
# 1997                  0                  0                    0
# 1998                  0                  0                    0
# 1999                  0                  0                    0
#
#       Profession_Entertainment  Profession_Executive  Profession_Healthcare  \
# 0                            0                     0                      1
# 1                            0                     0                      0
# 2                            0                     0                      0
# 3                            0                     0                      0
# 4                            1                     0                      0
# ...                        ...                   ...                    ...
# 1994                         0                     0                      0
# 1995                         0                     0                      0
# 1997                         0                     0                      1
# 1998                         0                     1                      0
# 1999                         1                     0                      0
#
#       Profession_Homemaker  Profession_Lawyer  Profession_Marketing  \
# 0                        0                  0                     0
# 1                        0                  0                     0
# 2                        0                  0                     0
# 3                        0                  1                     0
# 4                        0                  0                     0
# ...                    ...                ...                   ...
# 1994                     0                  0                     0
# 1995                     0                  0                     0
# 1997                     0                  0                     0
# 1998                     0                  0                     0
# 1999                     0                  0                     0
#
#       Gender_Female  Gender_Male
# 0                 0            1
# 1                 0            1
# 2                 1            0
# 3                 1            0
# 4                 1            0
# ...             ...          ...
# 1994              1            0
# 1995              1            0
# 1997              0            1
# 1998              0            1
# 1999              0            1
#
# [1467 rows x 11 columns]

# %%
scaler = StandardScaler()
x = scaler.fit_transform(df)

# %%
x
# Out:
# array([[-0.67373197, -0.29164906, -0.31313558, ..., -0.20650405,
#         -1.20547802,  1.20547802],
#        [-0.67373197, -0.29164906,  3.19350486, ..., -0.20650405,
#         -1.20547802,  1.20547802],
#        [-0.67373197, -0.29164906,  3.19350486, ..., -0.20650405,
#          0.82954644, -0.82954644],
#        ...,
#        [-0.67373197, -0.29164906, -0.31313558, ..., -0.20650405,
#         -1.20547802,  1.20547802],
#        [-0.67373197, -0.29164906, -0.31313558, ..., -0.20650405,
#         -1.20547802,  1.20547802],
#        [-0.67373197, -0.29164906, -0.31313558, ..., -0.20650405,
#         -1.20547802,  1.20547802]])

# %%
wcss = []

for i in range(1, 21):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', 
                    max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 21), wcss)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') 
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_36000\1948324274.py:6: ConvergenceWarning: Number of distinct clusters (18) found smaller than n_clusters (19). Possibly due to duplicate points in X.
#   kmeans.fit(x)
# C:\Users\user\AppData\Local\Temp\ipykernel_36000\1948324274.py:6: ConvergenceWarning: Number of distinct clusters (18) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   kmeans.fit(x)

# %%
dec = PCA(2)
dec1 = dec.fit_transform(x)

# %%
plt.scatter(dec1[:, 0], dec1[:, 1])

# %%
# scaler = StandardScaler()
# x = scaler.fit_transform(dec1)

# %%
wcss = []

for i in range(1, 10):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', 
                    max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(dec1)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 10), wcss)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') 
plt.show()

# %%
kmeans = KMeans(n_clusters = 4)
y_kmeans = kmeans.fit_predict(dec1)
y_kmeans
# Out:
# array([1, 1, 0, ..., 1, 1, 1])

# %%
kmeans.cluster_centers_
# Out:
# array([[-1.05229613, -0.92266263],
#        [ 1.80106511, -0.52562871],
#        [-1.40114767,  1.51952632],
#        [ 1.43534174,  1.90217253]])

# %%
len(dec1)
# Out:
# 1467

# %%
plt.scatter(dec1[:, 0], dec1[:, 1], c = kmeans.labels_, cmap = 'rainbow')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], color = 'black')
# plt.xlim(-20, 20)
# plt.ylim(-20, 20)
plt.show()

# %%
len(dec1[:, 1])
# Out:
# 1467

# %%
plt.scatter(dec1[:, 0], dec1[:, 1], marker='.')
plt.xlim(-.915, -0.91)

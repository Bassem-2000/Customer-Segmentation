# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import plotly.graph_objs as go
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
sns.set()

# %%
df = pd.read_csv('Customers.csv')
df
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
df.shape
# Out:
# (2000, 8)

# %%
df.describe(include = 'all')
# Out:
#          CustomerID  Gender          Age  Annual Income ($)  \
# count   2000.000000    2000  2000.000000        2000.000000
# unique          NaN       2          NaN                NaN
# top             NaN  Female          NaN                NaN
# freq            NaN    1186          NaN                NaN
# mean    1000.500000     NaN    48.960000      110731.821500
# std      577.494589     NaN    28.429747       45739.536688
# min        1.000000     NaN     0.000000           0.000000
# 25%      500.750000     NaN    25.000000       74572.000000
# 50%     1000.500000     NaN    48.000000      110045.000000
# 75%     1500.250000     NaN    73.000000      149092.750000
# max     2000.000000     NaN    99.000000      189974.000000
#
#         Spending Score (1-100) Profession  Work Experience  Family Size
# count              2000.000000       1965      2000.000000  2000.000000
# unique                     NaN          9              NaN          NaN
# ...

# %%
df.dtypes
# Out:
# CustomerID                 int64
# Gender                    object
# Age                        int64
# Annual Income ($)          int64
# Spending Score (1-100)     int64
# Profession                object
# Work Experience            int64
# Family Size                int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# CustomerID                 0
# Gender                     0
# Age                        0
# Annual Income ($)          0
# Spending Score (1-100)     0
# Profession                35
# Work Experience            0
# Family Size                0
# dtype: int64

# %%
df.drop(['CustomerID'], axis = 1, inplace=True)

# %%
sns.pairplot(df)

# %%
test_data = df[(df['Age']<=17) | (df['Age']>=91)]
test_data
# Out:
#       Gender  Age  Annual Income ($)  Spending Score (1-100)     Profession  \
# 202   Female   16              60000                       0       Engineer
# 210   Female    1              57000                      93       Engineer
# 211   Female    0              22000                      92         Artist
# 221   Female   95              72000                      51       Engineer
# 223   Female   93              93000                      37     Healthcare
# ...      ...  ...                ...                     ...            ...
# 1984  Female    2             153622                      51         Lawyer
# 1986  Female    4              68094                      61         Doctor
# 1991  Female   97             129444                      96  Entertainment
# 1992    Male   94             181183                      24      Marketing
# 1996  Female   91              73158                      32         Doctor
#
#       Work Experience  Family Size
# ...

# %%
# df.drop(df[df.Age <= 17].index, axis= 0, inplace=True)
# df.drop(df[df.Age >= 91].index, axis= 0, inplace=True)

# %%
x_train = df.drop('Age', axis = 1)
x_train = pd.get_dummies(x_train)
x_train
# Out:
#       Annual Income ($)  Spending Score (1-100)  Work Experience  Family Size  \
# 0                 15000                      39                1            4
# 1                 35000                      81                3            3
# 2                 86000                       6                1            1
# 3                 59000                      77                0            2
# 4                 38000                      40                2            6
# ...                 ...                     ...              ...          ...
# 1995             184387                      40                8            7
# 1996              73158                      32                7            7
# 1997              90961                      14                9            2
# 1998             182109                       4                7            2
# 1999             110610                      52                5            2
#
# ...

# %%
y_train = df['Age']
y_train
# Out:
# 0       19
# 1       21
# 2       20
# 3       23
# 4       31
#         ..
# 1995    71
# 1996    91
# 1997    87
# 1998    77
# 1999    90
# Name: Age, Length: 2000, dtype: int64

# %%
model = KNeighborsRegressor()
model.fit(x_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
x_test = test_data.drop('Age', axis = 1)
x_test = pd.get_dummies(x_test)
x_test
# Out:
#       Annual Income ($)  Spending Score (1-100)  Work Experience  Family Size  \
# 202               60000                       0                6            8
# 210               57000                      93                1            2
# 211               22000                      92                2            1
# 221               72000                      51                4            2
# 223               93000                      37                1            5
# ...                 ...                     ...              ...          ...
# 1984             153622                      51                6            6
# 1986              68094                      61                4            7
# 1991             129444                      96                5            6
# 1992             181183                      24                9            3
# 1996              73158                      32                7            7
#
# ...

# %%
y_pred = model.predict(x_test)
test_data['Age'] = y_pred
# test_data.drop('Age', axis = 1, inplace=True)
# test_data.rename(columns={'y_pred':'Age'})
test_data['Age'] = test_data['Age'].round().astype(int)
test_data
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_25620\895392557.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\user\AppData\Local\Temp\ipykernel_25620\895392557.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       Gender  Age  Annual Income ($)  Spending Score (1-100)     Profession  \
# 202   Female   46              60000                       0       Engineer
# 210   Female   49              57000                      93       Engineer
# ...

# %%
y_pred.min()
# Out:
# 11.0

# %%
df.describe(include = 'all')
# Out:
#         Gender          Age  Annual Income ($)  Spending Score (1-100)  \
# count     2000  2000.000000        2000.000000             2000.000000
# unique       2          NaN                NaN                     NaN
# top     Female          NaN                NaN                     NaN
# freq      1186          NaN                NaN                     NaN
# mean       NaN    48.960000      110731.821500               50.962500
# std        NaN    28.429747       45739.536688               27.934661
# min        NaN     0.000000           0.000000                0.000000
# 25%        NaN    25.000000       74572.000000               28.000000
# 50%        NaN    48.000000      110045.000000               50.000000
# 75%        NaN    73.000000      149092.750000               75.000000
# max        NaN    99.000000      189974.000000              100.000000
#
#        Profession  Work Experience  Family Size
# count        1965      2000.000000  2000.000000
# ...

# %%
plt.figure(1, figsize = (15, 6))
n = 0
for x in ['Age', 'Annual Income ($)', 'Spending Score (1-100)', 'Work Experience', 'Family Size']:
    n += 1
    plt.subplot(1, 5, n)
    plt.subplots_adjust(hspace=0.5, wspace=0.5)
    sns.distplot(df[x])
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_25620\1228374403.py:7: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# C:\Users\user\AppData\Local\Temp\ipykernel_25620\1228374403.py:7: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# ...

# %%
plt.figure(figsize = (15, 6))

plt.subplot(2, 1, 1)
sns.countplot(y = 'Gender', data = df)
plt.subplots_adjust(hspace=0.5, wspace=0.5)

plt.subplot(2, 1, 2)
sns.countplot(y = 'Profession', data = df)
plt.subplots_adjust(hspace=0.5, wspace=0.5)

plt.show()

# %%
df.Age[df.Age == 0].count()
# df['Age'].max()
# Out:
# 24

# %%
df['Spending Score (1-100)'].count()
# Out:
# 2000

# %%
sns.scatterplot(x = 'Annual Income ($)', y = 'Spending Score (1-100)', data=df)
# Out:
# <Axes: xlabel='Annual Income ($)', ylabel='Spending Score (1-100)'>

# %%
df.drop(["Profession","Gender"], inplace = True, axis=1)
df.drop(df[df.Age <= 17].index, axis= 0, inplace=True)
df.drop(df[df.Age >= 91].index, axis= 0, inplace=True)

# %%
# df = df[['Annual Income ($)', 'Spending Score (1-100)', 'Family Size']]
# df
df
# Out:
#       Age  Annual Income ($)  Spending Score (1-100)  Work Experience  \
# 0      19              15000                      39                1
# 1      21              35000                      81                3
# 2      20              86000                       6                1
# 3      23              59000                      77                0
# 4      31              38000                      40                2
# ...   ...                ...                     ...              ...
# 1994   19              54121                      89                6
# 1995   71             184387                      40                8
# 1997   87              90961                      14                9
# 1998   77             182109                       4                7
# 1999   90             110610                      52                5
#
#       Family Size
# 0               4
# 1               3
# 2               1
# 3               2
# 4               6
# ...

# %%
test_data.drop(['Profession', 'Gender'], axis=1, inplace=True)
test_data
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_25620\4073954100.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       Age  Annual Income ($)  Spending Score (1-100)  Work Experience  \
# 202    46              60000                       0                6
# 210    49              57000                      93                1
# 211    45              22000                      92                2
# 221    71              72000                      51                4
# 223    49              93000                      37                1
# ...   ...                ...                     ...              ...
# 1984   60             153622                      51                6
# 1986   48              68094                      61                4
# ...

# %%
df = pd.concat([df, test_data], axis = 0).sort_index()

# %%
# df[(df['Age']<=17) | (df['Age']>=91)] = test_data
# df

# %%
df.max()
# Out:
# Age                           90
# Annual Income ($)         189974
# Spending Score (1-100)       100
# Work Experience               17
# Family Size                    9
# dtype: int64

# %%
# scaler = StandardScaler()
# x = scaler.fit_transform(df)
from sklearn.preprocessing import MinMaxScaler
x = MinMaxScaler().fit_transform(df)
x.max()
# Out:
# 1.0

# %%
x[:, 0:4]
# Out:
# array([[0.10126582, 0.07895817, 0.39      , 0.05882353],
#        [0.12658228, 0.18423574, 0.81      , 0.17647059],
#        [0.11392405, 0.45269353, 0.06      , 0.05882353],
#        ...,
#        [0.96202532, 0.47880763, 0.14      , 0.52941176],
#        [0.83544304, 0.9585996 , 0.04      , 0.41176471],
#        [1.        , 0.58223757, 0.52      , 0.29411765]])

# %%
# plt.scatter(x[:, 0], x[:, 1])

# %%
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', 
                    max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(x[:, 0:2])
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') 
plt.show()

# %%
# dec = PCA(4)
# dec1 = dec.fit_transform(x)

# %%
x
# Out:
# array([[0.10126582, 0.07895817, 0.39      , 0.05882353, 0.375     ],
#        [0.12658228, 0.18423574, 0.81      , 0.17647059, 0.25      ],
#        [0.11392405, 0.45269353, 0.06      , 0.05882353, 0.        ],
#        ...,
#        [0.96202532, 0.47880763, 0.14      , 0.52941176, 0.125     ],
#        [0.83544304, 0.9585996 , 0.04      , 0.41176471, 0.125     ],
#        [1.        , 0.58223757, 0.52      , 0.29411765, 0.125     ]])

# %%
# dec1 = 
x
# Out:
# array([[0.10126582, 0.07895817, 0.39      , 0.05882353, 0.375     ],
#        [0.12658228, 0.18423574, 0.81      , 0.17647059, 0.25      ],
#        [0.11392405, 0.45269353, 0.06      , 0.05882353, 0.        ],
#        ...,
#        [0.96202532, 0.47880763, 0.14      , 0.52941176, 0.125     ],
#        [0.83544304, 0.9585996 , 0.04      , 0.41176471, 0.125     ],
#        [1.        , 0.58223757, 0.52      , 0.29411765, 0.125     ]])

# %%
# plt.subplot(1, 3, 1)
# plt.scatter(dec1[:, 0], dec1[:, 1])
# plt.subplot(1, 3, 2)
# plt.scatter(dec1[:, 2], dec1[:, 3])
# plt.subplot(1, 3, 3)
# plt.scatter(dec1[:, 3], dec1[:, 4])

# %%
# wcss = []

# for i in range(1, 10):
#     kmeans = KMeans(n_clusters = i, init = 'k-means++', 
#                     max_iter = 600, n_init = 10, random_state = 0)
#     kmeans.fit(dec1)
#     wcss.append(kmeans.inertia_)
# plt.plot(range(1, 10), wcss)
# plt.title('The elbow method')
# plt.xlabel('Number of clusters')
# plt.ylabel('WCSS') 
# plt.show()

# %%
kmeans = KMeans(n_clusters = 4, max_iter = 100, n_init="auto", random_state=0)
y_kmeans = kmeans.fit_predict(x[:, 0:2])
y_kmeans
# Out:
# array([1, 1, 1, ..., 2, 0, 2])

# %%
kmeans.labels_
# Out:
# array([1, 1, 1, ..., 2, 0, 2])

# %%
kmeans.cluster_centers_
# Out:
# array([[0.74798619, 0.79038388],
#        [0.30559927, 0.36058552],
#        [0.72210774, 0.4111647 ],
#        [0.31025068, 0.7960675 ]])

# %%
# plt.scatter(dec1[:, 0], dec1[:, 1], c = kmeans.labels_, cmap = 'rainbow')
# plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], color = 'black')
# # plt.xlim(-20, 20)
# # plt.ylim(-20, 20)
# plt.show()

# %%
# c = df[['Family Size', 'Work Experience', 'Age']]
fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
ax.scatter3D(x[:, 0], x[:, 1], x[:, 2], c = y_kmeans, cmap = 'tab20b', s =50)

# %%
plt.gca()
# Out:
# <Axes: >

# %%
Scene = dict(xaxis = dict(title  = 'Age -->'),yaxis = dict(title  = 'Spending Score--->'),zaxis = dict(title  = 'Annual Income-->'))

# model.labels_ is nothing but the predicted clusters i.e y_clusters
labels = kmeans.labels_
trace = go.Scatter3d(x=x[:, 0], y=x[:, 1], z=x[:, 2], mode='markers',marker=dict(color = labels, size= 10, line=dict(color= 'black',width = 10)))
layout = go.Layout(margin=dict(l=0,r=0),scene = Scene,height = 800,width = 800)
data = [trace]
fig = go.Figure(data = data, layout = layout)
fig.show()

# %%
round(2.6)
# Out:
# 3
